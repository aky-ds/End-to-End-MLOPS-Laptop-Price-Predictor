# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/admin/Downloads/archive/laptopPrice.csv")

# %%
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %%
df['brand'].value_counts()
# Out:
# ASUS      249
# DELL      151
# Lenovo    144
# HP        136
# acer       51
# MSI        50
# APPLE      28
# Avita      14
# Name: brand, dtype: int64

# %%
df['processor_brand'].value_counts()
# Out:
# Intel    610
# AMD      189
# M1        24
# Name: processor_brand, dtype: int64

# %%
df.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     823.000000         823.000000         823.000000
# mean    76745.177400         315.301337          37.609964
# std     45101.790525        1047.382654         121.728017
# min     16990.000000           0.000000           0.000000
# 25%     46095.000000           0.000000           0.000000
# 50%     64990.000000          17.000000           2.000000
# 75%     89636.000000         139.500000          18.000000
# max    441990.000000       15279.000000        1947.000000

# %%
df.isnull().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
plt.figure(figsize=(18,9))
sns.barplot(x=df['brand'],y=df['Price'])
# Out:
# <Axes: xlabel='brand', ylabel='Price'>

# %%
sns.countplot(x=df['brand'])
# Out:
# <Axes: xlabel='brand', ylabel='count'>

# %% [markdown]
# # Asus are the most laptops  and their average price are also reasonable.Apple are expensive so thats why it has been there at less rate

# %%
df['processor_brand'].value_counts()
# Out:
# Intel    610
# AMD      189
# M1        24
# Name: processor_brand, dtype: int64

# %%
sns.barplot(x=df['processor_brand'],y=df['Price'])
# Out:
# <Axes: xlabel='processor_brand', ylabel='Price'>

# %% [markdown]
# # Intel are the most commonly used processor due to its resonable price

# %%
df['processor_gnrtn'].value_counts()
# Out:
# 11th             334
# Not Available    225
# 10th             204
# 8th               41
# 7th                9
# 9th                6
# 12th               3
# 4th                1
# Name: processor_gnrtn, dtype: int64

# %%
df["processor_gnrtn"]=df['processor_gnrtn'].str.replace("Not Available","0th")

# %%
df_grouped = df.groupby(['brand', 'processor_brand', 'processor_name'])['Price'].mean()

# Unstack the DataFrame to create a bar chart
df_unstacked = df_grouped.unstack()

# Create a bar chart
plt.figure(figsize=(28, 10))
df_unstacked.plot(kind='bar', colormap='tab20')
plt.xlabel('Brand & Processor Brand')
plt.ylabel('Average Price')
plt.title('Average Price of Phones Grouped by Brand, Processor Brand, and Processor Name')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Processor Name')
plt.tight_layout()

plt.show()

# %% [markdown]
# # ASUS Intel Core i9 are the most expensive laptops and Avita Razor Ryzen 7 are the less expensive

# %%
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual             0th   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %%
df_grouped = df.groupby(['ssd', 'hdd', 'os'])['Price'].mean()

# Unstack the DataFrame to create a bar chart
df_unstacked = df_grouped.unstack()

# Create a bar chart
plt.figure(figsize=(28, 10))
df_unstacked.plot(kind='bar', colormap='tab20')
plt.xlabel('Ram & Processor Brand')
plt.ylabel('Average Price')
plt.title('Average Price of Phones Grouped by ssd, hdd, and os')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Processor Name')
plt.tight_layout()

plt.show()

# %% [markdown]
# # Windows is the commonly used OS while DOS and MAC is rarely used and 128gb ssd and 1024 gb is afforadable for a common person

# %%
df_grouped = df.groupby(['processor_gnrtn', 'ram_gb', 'ram_type'])['Price'].mean()

# Unstack the DataFrame to create a bar chart
df_unstacked = df_grouped.unstack()

# Create a bar chart
plt.figure(figsize=(28, 10))
df_unstacked.plot(kind='bar', colormap='tab20')
plt.xlabel('Ram & Processor Brand')
plt.ylabel('Average Price')
plt.title('Average Price of Phones Grouped by Ram, Processor generation, and Ram type')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Processor Name')
plt.tight_layout()

plt.show()

# %% [markdown]
# # DDR4 is the most commonly used RAM type a and to be 4gb with 8th generation is good and affordable for a commom person

# %%
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual             0th   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %%
sns.barplot(x=df['graphic_card_gb'],y=df['Price'],hue=df['weight'])
# Out:
# <Axes: xlabel='graphic_card_gb', ylabel='Price'>

# %% [markdown]
# # SO according to the analysis Graphic card has an influence in increasing the price of any laptop so for an average we can say 4GB Gaming is actually a resonable

# %%
df_grouped = df.groupby(['warranty', 'Touchscreen','rating'])['Price'].mean()

# Unstack the DataFrame to create a bar chart
df_unstacked = df_grouped.unstack()

# Create a bar chart
plt.figure(figsize=(28, 10))
df_unstacked.plot(kind='bar', colormap='tab20')
plt.xlabel('Warranty,touchscreen and rating')
plt.ylabel('Average Price')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Processor Name')
plt.tight_layout()

plt.show()

# %%
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual             0th   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
plt.scatter(x=df['Number of Ratings'],y=df['Price'])

# %%
sns.boxplot(df['Number of Ratings'])
# Out:
# <Axes: >

# %%
sns.boxplot(x=df['Number of Reviews'])
# Out:
# <Axes: xlabel='Number of Reviews'>

# %%
sns.boxplot(df['Price'])
# Out:
# <Axes: >

# %% [markdown]
# # SO lets move towards the feature engineering,feature labelling and feature selection

# %%
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual             0th   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
df['brand']=lb.fit_transform(df['brand'])

# %%
df['processor_brand']=lb.fit_transform(df['processor_brand'])

# %%
df['processor_name'].value_counts()
# Out:
# Core i5         290
# Core i3         164
# Core i7         110
# Ryzen 5          82
# Ryzen 7          56
# Ryzen 3          26
# Ryzen 9          26
# Celeron Dual     24
# M1               24
# Pentium Quad     13
# Core i9           8
# Name: processor_name, dtype: int64

# %%
df['processor_name']=lb.fit_transform(df['processor_name'])

# %%
df['processor_gnrtn'].value_counts()
# Out:
# processor_gnrtn
# 11               334
# Not Available    225
# 10               204
# 8                 41
# 7                  9
# 9                  6
# 12                 3
# 4                  1
# Name: count, dtype: int64

# %%
df['processor_gnrtn']=df['processor_gnrtn'].str.replace("th",'')
df['processor_gnrtn']=df['processor_gnrtn'].str.replace("Not Available",'0')
df['processor_gnrtn']=df['processor_gnrtn'].astype(int)

# %%
df.head()
# Out:
#     brand processor_brand processor_name  processor_gnrtn  ram_gb ram_type  \
# 0    ASUS           Intel        Core i3               10       4     DDR4
# 1  Lenovo           Intel        Core i3               10       4     DDR4
# 2  Lenovo           Intel        Core i3               10       4     DDR4
# 3    ASUS           Intel        Core i5               10       8     DDR4
# 4    ASUS           Intel   Celeron Dual                0       4     DDR4
#
#    ssd   hdd       os  os_bit  graphic_card_gb  weight  warranty Touchscreen  \
# 0    0  1024  Windows  64-bit                0  Casual         0          No
# 1    0  1024  Windows  64-bit                0  Casual         0          No
# 2    0  1024  Windows  64-bit                0  Casual         0          No
# 3  512     0  Windows  32-bit                2  Casual         0          No
# 4    0   512  Windows  64-bit                0  Casual         0          No
#
# ...

# %%
df['ram_gb'].value_counts()
# Out:
# ram_gb
# 8 GB     418
# 4 GB     226
# 16 GB    177
# 32 GB      2
# Name: count, dtype: int64

# %%
df['ram_gb']=df['ram_gb'].str.replace('GB','')
df['ram_gb']=df['ram_gb'].str.strip()
df['ram_gb']=df['ram_gb'].astype(int)

# %%
df['ram_type'].value_counts()
# Out:
# ram_type
# DDR4       709
# LPDDR4X     58
# LPDDR4      27
# LPDDR3      14
# DDR5         8
# DDR3         7
# Name: count, dtype: int64

# %%
df['ram_type']=lb.fit_transform(df['ram_type'])

# %%
df['ssd'].value_counts()
# Out:
# ssd
# 512 GB     398
# 256 GB     184
# 0 GB       124
# 1024 GB    111
# 128 GB       3
# 2048 GB      2
# 3072 GB      1
# Name: count, dtype: int64

# %%
df['ssd']=df['ssd'].str.replace('GB','')
df['ssd']=df['ssd'].str.strip()
df['ssd']=df['ssd'].astype(int)

# %%
df['hdd'].value_counts()
# Out:
# hdd
# 0 GB       621
# 1024 GB    160
# 512 GB      41
# 2048 GB      1
# Name: count, dtype: int64

# %%
df['hdd']=df['hdd'].str.replace('GB','')
df['hdd']=df['hdd'].str.strip()
df['hdd']=df['hdd'].astype(int)

# %%
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit  graphic_card_gb  weight  warranty  \
# 0    0 GB  1024 GB  Windows  64-bit                0  Casual         0
# 1    0 GB  1024 GB  Windows  64-bit                0  Casual         0
# 2    0 GB  1024 GB  Windows  64-bit                0  Casual         0
# 3  512 GB     0 GB  Windows  32-bit                2  Casual         0
# 4    0 GB   512 GB  Windows  64-bit                0  Casual         0
#
#   Touchscreen msoffice    Price rating  Number of Ratings  Number of Reviews
# ...

# %%
df['graphic_card_gb']=df['graphic_card_gb'].str.replace('GB','')
df['graphic_card_gb']=df['graphic_card_gb'].str.strip()
df['graphic_card_gb']=df['graphic_card_gb'].astype(int)

# %%
df['os']=lb.fit_transform(df['os'])

# %%
df['os_bit'].value_counts()
# Out:
# os_bit
# 64-bit    714
# 32-bit    109
# Name: count, dtype: int64

# %%
df['os_bit']=lb.fit_transform(df['os_bit'])

# %%
df['weight']=lb.fit_transform(df['weight'])

# %%
df['Touchscreen']=lb.fit_transform(df['Touchscreen'])
df['msoffice']=lb.fit_transform(df['msoffice'])

# %%
df['rating']=df['rating'].str.replace('star','')
df['rating']=df['rating'].str.strip()

# %%
df['rating']=df['rating'].str.replace('star','')
df['rating']=df['rating'].str.strip()

# %%
df['rating']=df['rating'].str.replace('s','')

# %%
df.head()
# Out:
#     brand processor_brand processor_name  processor_gnrtn  ram_gb ram_type  \
# 0    ASUS           Intel        Core i3               10       4     DDR4
# 1  Lenovo           Intel        Core i3               10       4     DDR4
# 2  Lenovo           Intel        Core i3               10       4     DDR4
# 3    ASUS           Intel        Core i5               10       8     DDR4
# 4    ASUS           Intel   Celeron Dual                0       4     DDR4
#
#    ssd   hdd       os  os_bit  graphic_card_gb  weight     warranty  \
# 0    0  1024  Windows  64-bit                0  Casual  No warranty
# 1    0  1024  Windows  64-bit                0  Casual  No warranty
# 2    0  1024  Windows  64-bit                0  Casual  No warranty
# 3  512     0  Windows  32-bit                2  Casual  No warranty
# 4    0   512  Windows  64-bit                0  Casual  No warranty
#
#   Touchscreen msoffice  Price rating  Number of Ratings  Number of Reviews
# ...

# %%
df['warranty']=df['warranty'].str.replace('No warranty','0')
df['warranty']=df['warranty'].str.replace('years','')
df['warranty']=df['warranty'].str.replace('year','')
df['warranty']=df['warranty'].str.strip()
df['warranty']=df['warranty'].astype(int)

# %%
df['Price']
# Out:
# 0       34649
# 1       38999
# 2       39999
# 3       69990
# 4       26990
#         ...
# 818    135990
# 819    144990
# 820    149990
# 821    142990
# 822     57490
# Name: Price, Length: 823, dtype: int64

# %%
sns.histplot(df['Price'],kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
q1=df['Price'].quantile(0.25)
q3=df['Price'].quantile(0.75)
iqr=q3-q1
upper=q3+1.5*iqr
lower=q1-1.5*iqr

# %%
df['Price']=df['Price'].clip(upper=upper,lower=lower)

# %%
sns.boxplot(df['Price'])
# Out:
# <Axes: >

# %%
q1=df['Number of Ratings'].quantile(0.25)
q3=df['Number of Ratings'].quantile(0.75)
iqr=q3-q1
upper=q3+1.5*iqr
lower=q1-1.5*iqr

# %%
df['Number of Ratings']=df['Number of Ratings'].clip(upper=upper,lower=lower)

# %%
sns.boxplot(df['Number of Ratings'])
# Out:
# <Axes: >

# %%
q1=df['Number of Reviews'].quantile(0.25)
q3=df['Number of Reviews'].quantile(0.75)
iqr=q3-q1
upper=q3+1.5*iqr
lower=q1-1.5*iqr

# %%
df['Number of Reviews']=df['Number of Reviews'].clip(upper=upper,lower=lower)

# %%
sns.boxplot(df['Number of Reviews'])
# Out:
# <Axes: >

# %%
df.head()
# Out:
#     brand processor_brand processor_name  processor_gnrtn  ram_gb ram_type  \
# 0    ASUS           Intel        Core i3               10       4     DDR4
# 1  Lenovo           Intel        Core i3               10       4     DDR4
# 2  Lenovo           Intel        Core i3               10       4     DDR4
# 3    ASUS           Intel        Core i5               10       8     DDR4
# 4    ASUS           Intel   Celeron Dual                0       4     DDR4
#
#    ssd   hdd       os  os_bit  graphic_card_gb  weight  warranty Touchscreen  \
# 0    0  1024  Windows  64-bit                0  Casual         0          No
# 1    0  1024  Windows  64-bit                0  Casual         0          No
# 2    0  1024  Windows  64-bit                0  Casual         0          No
# 3  512     0  Windows  32-bit                2  Casual         0          No
# 4    0   512  Windows  64-bit                0  Casual         0          No
#
# ...

# %%
# Out:
# ram_type
# DDR4       709
# LPDDR4X     58
# LPDDR4      27
# LPDDR3      14
# DDR5         8
# DDR3         7
# Name: count, dtype: int64

# %%
df.to_csv("C:/Users/admin/desktop/Data.csv")

# %%
df=pd.read_csv("C:/Users/admin/desktop/Data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0   brand processor_brand processor_name  processor_gnrtn  ram_gb  \
# 0           0    ASUS           Intel        Core i3               10       4
# 1           1  Lenovo           Intel        Core i3               10       4
# 2           2  Lenovo           Intel        Core i3               10       4
# 3           3    ASUS           Intel        Core i5               10       8
# 4           4    ASUS           Intel   Celeron Dual                0       4
#
#   ram_type  ssd   hdd       os  os_bit  graphic_card_gb  weight  warranty  \
# 0     DDR4    0  1024  Windows  64-bit                0  Casual         0
# 1     DDR4    0  1024  Windows  64-bit                0  Casual         0
# 2     DDR4    0  1024  Windows  64-bit                0  Casual         0
# 3     DDR4  512     0  Windows  32-bit                2  Casual         0
# 4     DDR4    0   512  Windows  64-bit                0  Casual         0
#
# ...

# %%
df['msoffice'].value_counts()
# Out:
# msoffice
# No     542
# Yes    281
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         823 non-null    int64
#  1   brand              823 non-null    object
#  2   processor_brand    823 non-null    object
#  3   processor_name     823 non-null    object
#  4   processor_gnrtn    823 non-null    int64
#  5   ram_gb             823 non-null    int64
#  6   ram_type           823 non-null    object
#  7   ssd                823 non-null    int64
#  8   hdd                823 non-null    int64
#  9   os                 823 non-null    object
#  10  os_bit             823 non-null    object
#  11  graphic_card_gb    823 non-null    int64
#  12  weight             823 non-null    object
#  13  warranty           823 non-null    int64
#  14  Touchscreen        823 non-null    object
#  15  msoffice           823 non-null    object
# ...

# %%
df['rating']=df['rating'].str.replace('s','')

# %%
df['rating']=df['rating'].str.strip()
df['rating']=df['rating'].astype(int)

# %%
correlation_matrix = df.corr(method='spearman')  # Use 'pearson' for Pearson correlation

# Create a new figure for the plot
plt.figure(figsize=(20, 8))

# Create the heatmap
heatmap = sns.heatmap(correlation_matrix,
                      vmin=-1, vmax=1,  # Set the color range for correlation values
                      annot=True,  # Annotate heatmap with correlation values
                      cmap='coolwarm')  # Colormap for positive and negative correlations

# Add labels and title


# Rotate x-axis labels for better readability (optional)
plt.xticks(rotation=45)
plt.tight_layout()

# Display the heatmap
plt.show()

# %%
df.corr()['Price']
# Out:
# brand               -0.077735
# processor_brand      0.064775
# processor_name       0.269262
# processor_gnrtn      0.084365
# ram_gb               0.527023
# ram_type             0.256816
# ssd                  0.628544
# hdd                 -0.289427
# os                  -0.293004
# os_bit               0.009495
# graphic_card_gb      0.473266
# weight              -0.284894
# warranty             0.097802
# Touchscreen          0.236016
# msoffice            -0.095930
# Price                1.000000
# rating              -0.061775
# Number of Ratings   -0.272704
# Number of Reviews   -0.248394
# Name: Price, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(df.drop("Price",axis=1),df['Price'],test_size=0.25,random_state=45)

# %%
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor
from sklearn.linear_model import Lasso,Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import RandomizedSearchCV

# %%
models={
    "RFR":RandomForestRegressor(),
    "GBR":GradientBoostingRegressor(),
    "ADR":AdaBoostRegressor(),
    "Lasso":Lasso(),
    "Ridge":Ridge(),
    "KNN":KNeighborsRegressor()
    
}

# %%
params_grid={
    "RFR":{
        "n_estimators":[50,100,200,300],
        "max_depth":[1,3,5,7]
    },
    "GBR":{
        "n_estimators":[50,100,200,300],
        "learning_rate":[1.0,0.7,1.4,1.5]
    },
    "ADR":{
        "n_estimators":[50,100,200,300],
        "learning_rate":[1.0,0.7,1.4,1.5]
},
    "Lasso":{
        "alpha":[1.0,0.1,0.5]
    },
    "Ridge":{
        "alpha":[1.0,0.1,0.5]
    },
    "KNN":{
        "n_neighbors":[1,2,3,4,5,6,7,8]
    },
   
}

# %%
for model_name,model in models.items():
    gr=RandomizedSearchCV(model,params_grid[model_name],cv=5,scoring='r2')
    gr.fit(X_train,y_train)
    print(gr.best_estimator_,gr.best_params_,gr.best_score_)
# Out:
# RandomForestRegressor(max_depth=7, n_estimators=200) {'n_estimators': 200, 'max_depth': 7} 0.8021713305895375
# GradientBoostingRegressor(learning_rate=0.7, n_estimators=200) {'n_estimators': 200, 'learning_rate': 0.7} 0.8054596430822552
# AdaBoostRegressor() {'n_estimators': 50, 'learning_rate': 1.0} 0.6906786116386477
# Lasso() {'alpha': 1.0} 0.7355583803555206
# Ridge() {'alpha': 1.0} 0.7358119588104508
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:307: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:307: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ...

# %% [markdown]
# # Now without Removing any negative correlated columns we are getting the accuracy of 80.54

# %% [markdown]
# # So lets remove the unccesary columns

# %%
df.corr()["Price"]
# Out:
# brand               -0.077735
# processor_brand      0.064775
# processor_name       0.269262
# processor_gnrtn      0.084365
# ram_gb               0.527023
# ram_type             0.256816
# ssd                  0.628544
# hdd                 -0.289427
# os                  -0.293004
# os_bit               0.009495
# graphic_card_gb      0.473266
# weight              -0.284894
# warranty             0.097802
# Touchscreen          0.236016
# msoffice            -0.095930
# Price                1.000000
# rating              -0.061775
# Number of Ratings   -0.272704
# Number of Reviews   -0.248394
# Name: Price, dtype: float64

# %%
df.drop("Number of Ratings",axis='columns',inplace=True)
df.drop("Number of Reviews",axis='columns',inplace=True)
df.drop("rating",axis='columns',inplace=True)
df.drop("os",axis='columns',inplace=True)
df.drop("msoffice",axis='columns',inplace=True)

# %%
X_train,X_test,y_train,y_test=train_test_split(df.drop("Price",axis=1),df['Price'],test_size=0.25,random_state=45)

# %%
models={
    "RFR":RandomForestRegressor(),
    "GBR":GradientBoostingRegressor(),
    "ADR":AdaBoostRegressor(),
    "Lasso":Lasso(),
    "Ridge":Ridge(),
    "KNN":KNeighborsRegressor()
    
}
params_grid={
    "RFR":{
        "n_estimators":[50,100,200,300],
        "max_depth":[1,3,5,7]
    },
    "GBR":{
        "n_estimators":[50,100,200,300],
        "learning_rate":[1.0,0.7,1.4,1.5]
    },
    "ADR":{
        "n_estimators":[50,100,200,300],
        "learning_rate":[1.0,0.7,1.4,1.5]
},
    "Lasso":{
        "alpha":[1.0,0.1,0.5]
    },
    "Ridge":{
        "alpha":[1.0,0.1,0.5]
    },
    "KNN":{
        "n_neighbors":[1,2,3,4,5,6,7,8]
    },
   
}
for model_name,model in models.items():
    gr=RandomizedSearchCV(model,params_grid[model_name],cv=5,scoring='r2')
    gr.fit(X_train,y_train)
    print(gr.best_estimator_,gr.best_params_,gr.best_score_)
# Out:
# RandomForestRegressor(max_depth=7) {'n_estimators': 100, 'max_depth': 7} 0.7964004293694519
# GradientBoostingRegressor(learning_rate=0.7, n_estimators=50) {'n_estimators': 50, 'learning_rate': 0.7} 0.7954343403835157
# AdaBoostRegressor(learning_rate=0.7) {'n_estimators': 50, 'learning_rate': 0.7} 0.6814474418704484
# Lasso() {'alpha': 1.0} 0.7064327445540569
# Ridge(alpha=0.5) {'alpha': 0.5} 0.7064753040895845
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:307: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:307: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# ...

# %% [markdown]
# # Lets Check and predict

# %%
GBR=GradientBoostingRegressor(n_estimators=50,learning_rate=0.7)

# %%
GBR.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.7, n_estimators=50)

# %%
ypre=GBR.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
print(mean_squared_error(ypre,y_test),r2_score(ypre,y_test))
# Out:
# 267924374.62175655 0.7370829764475342

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
ypre=model.predict(X_test)

# %%
r2_score(ypre,y_test)
# Out:
# 0.7351107432538528

# %% [markdown]
# # After check the models I think GradientBoostingRegressor works best on my data
